# %%
import os
# %pwd
# Out:
# '/Users/rajusubba/Documents/End-to-End MLOps/customer-churn-project'

# %%
os.chdir('/Users/rajusubba/Documents/End-to-End MLOps/customer-churn-project')

# %%
from dataclasses import dataclass
from pathlib import Path    

@dataclass
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.customerchurn.constants import *
from src.customerchurn.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(self, 
                 config_file_path = CONFIG_FILE_PATH,
                 params_file_path = PARAMS_FILE_PATH,
                 schema_file_path = SCHEMA_FILE_PATH,
                 ):
        self.config = read_yaml(config_file_path)
        self.params = read_yaml(params_file_path)
        self.schema = read_yaml(schema_file_path)
        
        create_directories([self.config.artifacts_root])
        
    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation
        create_directories([config.root_dir])
        data_transformation_config = DataTransformationConfig(
            root_dir = config.root_dir,
            data_path = config.data_path
        )
        return data_transformation_config

# %%
import os
from src.customerchurn.logging.logger import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config
    ## All data transformation methods can be added here
    def train_test_split(self):
        data = pd.read_csv(self.config.data_path)
        train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)
        train_data.to_csv(os.path.join(self.config.root_dir, 'train.csv'), index=False)
        test_data.to_csv(os.path.join(self.config.root_dir, 'test.csv'), index=False)
        logger.info(f"Train and test data saved at {self.config.root_dir}")
        
        logger.info(train_data.shape)
        logger.info(test_data.shape)
        
        print(train_data.shape)
        print(test_data.shape)

# %%
try:
    config_manager = ConfigurationManager()
    data_transformation_config = config_manager.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_split()
except Exception as e:
    logger.exception(e)
    raise e
# Out:
# [2026-02-04 14:06:40,296: INFO: common: YAML file config/config.yaml loaded successfully.]
# [2026-02-04 14:06:40,299: INFO: common: YAML file params.yaml loaded successfully.]
# [2026-02-04 14:06:40,302: INFO: common: YAML file schema.yaml loaded successfully.]
# [2026-02-04 14:06:40,303: INFO: common: Directory created at: artifacts]
# [2026-02-04 14:06:40,303: INFO: common: Directory created at: artifacts/data_transformation]
# [2026-02-04 14:06:40,354: INFO: 3392004103: Train and test data saved at artifacts/data_transformation]
# [2026-02-04 14:06:40,354: INFO: 3392004103: (8000, 13)]
# [2026-02-04 14:06:40,355: INFO: 3392004103: (2000, 13)]
# (8000, 13)
# (2000, 13)
